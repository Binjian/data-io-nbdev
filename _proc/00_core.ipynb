# %% [raw]
# ---
# description: core module for data pipeline processing
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(say_hello)
# Out:
# ---
#
# [source](https://github.com/Binjian/data-io-nbdev/tree/main/blob/main/data_io_nbdev/core.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### say_hello
#
# >      say_hello (to:str)
#
# Say hello to somebody

# %%
assert say_hello("Jeremy")=="Hello Jeremy!"

# %%
from fastcore.test import *

# %%
test_eq(say_hello("Jeremy"), "Hello Jeremy!")

# %%
from IPython.display import display, SVG

# %%
display(SVG('<svg height="100" xmlns="http://www.w3.org/2000/svg"><circle cx="50" cy="50" r="40"/></svg> '))

# %% [markdown]
# ## show a graph with mermaid

# %% [markdown]
# ```{mermaid}
# flowchart LR
#   A[Hard edge] --> B(Round edge)
#   B --> C{Decision}
#   C --> D[Result one]
#   C --> E[Result two]
# ```

# %% [markdown]
# ```{dot}
# graph G {
#   layout=neato
#   run -- intr;
#   intr -- runbl;
#   runbl -- run;
#   run -- kernel;
#   kernel -- zombie;
#   kernel -- sleep;
#   kernel -- runmem;
#   sleep -- swap;
#   swap -- runswap;
#   runswap -- new;
#   runswap -- runmem;
#   new -- runmem;
#   sleep -- runmem;
# }
# ```

# %% [markdown]
# ```{mermaid}
# sequenceDiagram
#   participant Alice
#   participant Bob
#   Alice->>John: Hello John, how are you?
#   loop Healthcheck
#     John->>John: Fight against hypochondria
#   end
#   Note right of John: Rational thoughts <br/>prevail!
#   John-->>Alice: Great!
#   John->>Bob: How about you?
#   Bob-->>John: Jolly good!
# ```
